# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .master("local[1]")
    .appName("pyspark-practice")
    .config("spark.ui.enabled", "false")
    .config("spark.driver.bindAddress", "127.0.0.1")
    .config("spark.driver.host", "127.0.0.1")
    .getOrCreate()
)

print("spark ok")

# %%
data = [
    (1, "u001", "2025-03-01 10:01:00", "view", "phone", 0, "mobile", "MD"),
    (2, "u001", "2025-03-01 10:05:00", "add_to_cart", "phone", 0, "mobile", "MD"),
    (3, "u001", "2025-03-01 10:07:00", "purchase", "phone", 699, "mobile", "MD"),
    (4, "u002", "2025-03-02 09:30:00", "purchase", "laptop", 849, "desktop", "RO"),
]

columns = [
    "event_id", "user_id", "event_ts",
    "event_type", "product_category",
    "price", "device", "country"
]

df = spark.createDataFrame(data, columns) \
    .withColumn("event_ts", F.to_timestamp("event_ts"))

df.show()

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .master("local[1]")
    .appName("pyspark-practice")
    .config("spark.ui.enabled", "false")
    .config("spark.driver.bindAddress", "127.0.0.1")
    .config("spark.driver.host", "127.0.0.1")
    .getOrCreate()
)

print("spark ok")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       1 from pyspark.sql import SparkSession
#       3 spark = (
#       4     SparkSession.builder
#       5     .master("local[1]")
#       6     .appName("pyspark-practice")
#       7     .config("spark.ui.enabled", "false")
#       8     .config("spark.driver.bindAddress", "127.0.0.1")
#       9     .config("spark.driver.host", "127.0.0.1")
# ---> 10     .getOrCreate()
#      11 )
#      13 print("spark ok")
#
# File c:\Users\Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)
#     220         memory_profiler_cls,
#     221     )
#
# File c:\Users\Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:
